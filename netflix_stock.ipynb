# %%
import yfinance as yf

# %%
Netflix = yf.Ticker('NFLX')

# %%
data = Netflix.history(period="max")

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2002-05-23 00:00:00-04:00    1.156429    1.242857    1.145714    1.196429
# 2002-05-24 00:00:00-04:00    1.214286    1.225000    1.197143    1.210000
# 2002-05-28 00:00:00-04:00    1.213571    1.232143    1.157143    1.157143
# 2002-05-29 00:00:00-04:00    1.164286    1.164286    1.085714    1.103571
# 2002-05-30 00:00:00-04:00    1.107857    1.107857    1.071429    1.071429
# ...                               ...         ...         ...         ...
# 2024-04-25 00:00:00-04:00  549.460022  566.539978  545.710022  564.799988
# 2024-04-26 00:00:00-04:00  558.210022  562.919983  553.190002  561.229980
# 2024-04-29 00:00:00-04:00  559.179993  559.640015  554.239990  559.489990
# 2024-04-30 00:00:00-04:00  560.000000  560.000000  549.380005  550.640015
# 2024-05-01 00:00:00-04:00  547.840027  560.390015  544.250000  551.710022
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5523 entries, 2002-05-23 00:00:00-04:00 to 2024-05-01 00:00:00-04:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          5523 non-null   float64
#  1   High          5523 non-null   float64
#  2   Low           5523 non-null   float64
#  3   Close         5523 non-null   float64
#  4   Volume        5523 non-null   int64
#  5   Dividends     5523 non-null   float64
#  6   Stock Splits  5523 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 345.2 KB

# %%
data.index
# Out:
# DatetimeIndex(['2002-05-23 00:00:00-04:00', '2002-05-24 00:00:00-04:00',
#                '2002-05-28 00:00:00-04:00', '2002-05-29 00:00:00-04:00',
#                '2002-05-30 00:00:00-04:00', '2002-05-31 00:00:00-04:00',
#                '2002-06-03 00:00:00-04:00', '2002-06-04 00:00:00-04:00',
#                '2002-06-05 00:00:00-04:00', '2002-06-06 00:00:00-04:00',
#                ...
#                '2024-04-18 00:00:00-04:00', '2024-04-19 00:00:00-04:00',
#                '2024-04-22 00:00:00-04:00', '2024-04-23 00:00:00-04:00',
#                '2024-04-24 00:00:00-04:00', '2024-04-25 00:00:00-04:00',
#                '2024-04-26 00:00:00-04:00', '2024-04-29 00:00:00-04:00',
#                '2024-04-30 00:00:00-04:00', '2024-05-01 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=5523, freq=None)

# %%
data['Close'].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
data = data.loc['2010-1-1':'2023-12-31']

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00-05:00    7.931429    7.961429    7.565714    7.640000
# 2010-01-05 00:00:00-05:00    7.652857    7.657143    7.258571    7.358571
# 2010-01-06 00:00:00-05:00    7.361429    7.672857    7.197143    7.617143
# 2010-01-07 00:00:00-05:00    7.731429    7.757143    7.462857    7.485714
# 2010-01-08 00:00:00-05:00    7.498571    7.742857    7.465714    7.614286
# ...                               ...         ...         ...         ...
# 2023-12-22 00:00:00-05:00  494.000000  496.019989  485.450012  486.760010
# 2023-12-26 00:00:00-05:00  489.390015  491.480011  486.380005  491.190002
# 2023-12-27 00:00:00-05:00  491.239990  494.019989  489.250000  491.790009
# 2023-12-28 00:00:00-05:00  492.000000  492.890015  489.070007  490.510010
# 2023-12-29 00:00:00-05:00  490.369995  492.230011  481.940002  486.880005
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %%
data['Close'].plot(figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
data.to_csv("Netflix Stock", sep=',',index=True, encoding='UTF-8')
